# %% [markdown]
# ## 꺾기

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
칼럼 =['연번','자치구','담당','구분','집행일시','시분값', \
       '집행장소','집행주소','결재방법','집행금액','집행목적/집행내역/내용','대상인원','50만원이상 결재시 증빙서류','비고']
기본경로 = r'C:\Users\user\1코드들\2018년_정공센_알권리감시단_업무추진비_코드\Files\공개자료_업데이트\\'
파일위치경로 = r'C:/Users/user/Desktop/구청별 업무추진비(엑셀)/'
구청목록 = [ 
    '종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구',
    '은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서초구',
    '강남구','송파구','강동구','서울특별시'
            ]   #26개
요일 = {'Monday':'월', 'Tuesday':'화', 'Wednesday':'수', 'Thursday':'목', 'Friday':'금', 'Saturday':'토', 'Sunday':'일'}

# %%
구청별=dict()

for 구청이름 in 구청목록:
    try:
        구청별[구청이름]=pd.read_excel(파일위치경로+구청이름+'(정제).xlsx')
    except FileNotFoundError:
        print('파일이 없습니다:'+구청이름)
    except :
        print(구청이름)
# Out:
# 파일이 없습니다:서울특별시

# %%
구청별['종로구']
# Out:
#       자치구   담당       구분                 집행일시       시분값        집행장소  \
# 0     종로구  이상수       의장  2014-04-01 00:00:00  12:41:40   （주）더부페종로점
# 1     종로구  이상수       의장  2014-04-02 00:00:00  10:49:42     종로바베큐보쌈
# 2     종로구  이상수       의장  2014-04-02 00:00:00  12:24:32          밥줘
# 3     종로구  이상수       의장  2014-04-03 00:00:00  12:13:38      종로해초세상
# 4     종로구  이상수       의장  2014-04-05 00:00:00  12:41:22        옛맛식당
# 5     종로구  이상수       의장  2014-04-05 00:00:00  19:17:19        신라갈비
# 6     종로구  이상수       의장  2014-04-07 00:00:00  12:15:12       무교동낙지
# 7     종로구  이상수       의장  2014-04-08 00:00:00  12:38:24          밥줘
# 8     종로구  이상수       의장  2014-04-08 00:00:00  19:04:59          밥줘
# 9     종로구  이상수       의장  2014-04-09 00:00:00  13:08:55         토담골
# 10    종로구  이상수       의장  2014-04-09 00:00:00  12:18:40     서린낙지견지점
# 11    종로구  이상수       의장  2014-04-10 00:00:00  13:16:51        연세식당
# 12    종로구  이상수       의장  2014-04-10 00:00:00  12:12:14        삼성식당
# 13    종로구  이상수       의장  2014-04-11 00:00:00  16:45:34        서촌강정
# 14    종로구  이상수       의장  2014-04-12 00:00:00  18:31:14        송정갈비
# 15    종로구  이상수       의장  2014-04-14 00:00:00  12:46:57     종로바베큐보쌈
# 16    종로구  이상수       의장  2014-04-14 00:00:00  12:43:09    청운동남원추어탕
# 17    종로구  이상수       의장  2014-04-15 00:00:00  12:47:49   명품장강　주식회사
# 18    종로구  이상수       의장  2014-04-16 00:00:00  13:52:19         토담골
# 19    종로구  이상수       의장  2014-04-16 00:00:00  12:12:42       무교동낙지
# 20    종로구  이상수       의장  2014-04-17 00:00:00  11:18:44    청운동남원추어탕
# 21    종로구  이상수       의장  2014-04-18 00:00:00  18:36:06       옛날순대국
# 22    종로구  이상수       의장  2014-04-18 00:00:00  12:11:31       고향보리밥
# 23    종로구  이상수       의장  2014-04-19 00:00:00  13:00:08        옛맛식당
# 3118      서울 종로구 종로5길 7   카드  283500  의정활동 관련 간담회    -               -  -  금
# 3119     서울 종로구 종로5길 34   카드   13900  의정활동 관련 간담회    -               -  -  금
# 3120    서울 종로구 종로57길 28   카드   96000  의정활동 관련 간담회    -               -  -  월
# 3121     서울 종로구 종로5길 34   카드   12200  의정활동 관련 간담회    -               -  -  금
# 3122      서울 종로구 종로5길 7   카드  176500  의정활동 관련 간담회    -               -  -  월
# 3123  서울 종로구 종로41길 8-36   카드   83000  의정활동 관련 간담회    -               -  -  월
# 3124      서울 종로구 종로5길 7   카드    8000  의정활동 관련 간담회    -               -  -  월
# 3125          서울 종로구 종로   카드   20000  의정활동 관련 간담회    -               -  -  수
# 3126          서울 종로구 종로   카드  177000  의정활동 관련 간담회    -               -  -  목
# 3127        서울 종로구 종로1길   카드  116000  의정활동 관련 간담회    -               -  -  금
# 3128        서울 종로구 종로1길   카드  427000  의정활동 관련 간담회    -               -  -  월
# 3129     서울 종로구 종로5길 34   카드   13100  의정활동 관련 간담회    -               -  -  화
# 3130      서울 종로구 종로5길 7   카드  300000  의정활동 관련 간담회    -               -  -  금
# 3131      서울 종로구 종로5길 7   카드  100000  의정활동 관련 간담회    -               -  -  화
# 3132      서울 종로구 삼봉로 66   카드   10000  의정활동 관련 간담회    -               -  -  수
# 3133         서울 종로구 숭인동   카드  201000  의정활동 관련 간담회    -               -  -  목
# 3134        서울 종로구 종로1길   카드  100000  의정활동 관련 간담회    -               -  -  금
# 3135     서울 종로구 필운대로 43   카드   35300  의정활동 관련 간담회    -               -  -  금
# 3136     서울 종로구 종로1길 50   카드    7600  의정활동 관련 간담회    -               -  -  월
# 3137      서울 종로구 종로5길 7   카드   21000  의정활동 관련 간담회    -               -  -  수
# 3138     서울 종로구 종로3길 30   카드  200000  의정활동 관련 간담회    -               -  -  금
# 3139      서울 종로구 종로5길 7   카드  300000  의정활동 관련 간담회    -               -  -  화
# 3140         서울 종로구 숭인동   카드   14000  의정활동 관련 간담회    -               -  -  월
# 3141    서울 종로구 종로44길 91   카드  200000  의정활동 관련 간담회    -               -  -  화
# 3142    서울 종로구 삼봉로 42-1   카드   20000  의정활동 관련 간담회    -               -  -  수
# 3143        서울 종로구 김상옥로   카드  105000  의정활동 관련 간담회    -               -  -  목
# 3144          서울 종로구 종로   카드   17000  의정활동 관련 간담회    -               -  -  목
# 3145          서울 종로구 종로   카드  105000  의정활동 관련 간담회    -               -  -  금
# 3146      서울 종로구 종로 390   카드    6930  의정활동 관련 간담회    -               -  -  수
#
# [3147 rows x 14 columns]

# %% [markdown]
# ## 꺽기

# %%
for 임시_구청이름, 각_프레임 in 구청별.items():
    각_프레임.시분값 = 각_프레임.시분값.astype(str)
    구분 =list(set(각_프레임.구분))
    직접확인_프레임 = pd.DataFrame(columns=칼럼)
    간접확인_프레임 = pd.DataFrame(columns=칼럼)
    for 임시_구분_이름 in 구분:
        임시_구분 =각_프레임[각_프레임.구분 == 임시_구분_이름]
        일시별_금액합계 =임시_구분.groupby('집행일시').sum()
        임시_프레임 =pd.DataFrame(columns=칼럼)
        for 임시_일시 in list(일시별_금액합계[일시별_금액합계.집행금액 >300000].index):
            #print(각_프레임[각_프레임.집행일시 == i])
            임시_프레임 =각_프레임[각_프레임.집행일시 == 임시_일시]
            임시_프레임 = 임시_프레임[임시_프레임.구분 ==임시_구분_이름]
            직접확인_프레임 =직접확인_프레임.append(임시_프레임)  #뽑힌거 일단 모두 저장

        임시_장소종류 = set(임시_프레임.집행장소)
        for 임시_장소 in 임시_장소종류:
            if 임시_프레임[임시_프레임.집행장소 == 임시_장소].집행일시.count() > 1:
                간접확인_프레임 = 간접확인_프레임.append(임시_프레임[임시_프레임.집행장소 == 임시_장소])
    if not 직접확인_프레임.empty:
        직접확인_프레임.to_excel(r"C:/Users/user/Desktop/구청별 업무추진비(엑셀)/꺽기/하루에_일정비용이상사용_직접확인필요/"+임시_구청이름+"_30만원이상.xlsx")
    if not 간접확인_프레임.empty:
        간접확인_프레임.to_excel(r"C:/Users/user/Desktop/구청별 업무추진비(엑셀)/꺽기/하루에_일정비용이상사용_상호명같은것만분류/"+임시_구청이름+"_30만원이상.xlsx")

# %%
for 임시_구청이름, 각_프레임 in 구청별.items():
    각_프레임.시분값 = 각_프레임.시분값.astype(str)
    구분 =list(set(각_프레임.구분))
    직접확인_프레임 = pd.DataFrame(columns=칼럼)
    간접확인_프레임 = pd.DataFrame(columns=칼럼)
    for 임시_구분_이름 in 구분:
        임시_구분 =각_프레임[각_프레임.구분 == 임시_구분_이름]
        일시별_금액합계 =임시_구분.groupby('집행일시').sum()
        임시_프레임 =pd.DataFrame(columns=칼럼)
        for 임시_일시 in list(일시별_금액합계[일시별_금액합계.집행금액 >500000].index):
            #print(각_프레임[각_프레임.집행일시 == i])
            임시_프레임 =각_프레임[각_프레임.집행일시 == 임시_일시]
            임시_프레임 = 임시_프레임[임시_프레임.구분 ==임시_구분_이름]
            직접확인_프레임 =직접확인_프레임.append(임시_프레임)  #뽑힌거 일단 모두 저장

        임시_장소종류 = set(임시_프레임.집행장소)
        for 임시_장소 in 임시_장소종류:
            if 임시_프레임[임시_프레임.집행장소 == 임시_장소].집행일시.count() > 1:
                간접확인_프레임 = 간접확인_프레임.append(임시_프레임[임시_프레임.집행장소 == 임시_장소])
    if not 직접확인_프레임.empty:
        직접확인_프레임.to_excel(r"C:/Users/user/Desktop/구청별 업무추진비(엑셀)/꺽기/하루에_일정비용이상사용_직접확인필요/"+임시_구청이름+"_50만원이상.xlsx")
    if not 간접확인_프레임.empty:
        간접확인_프레임.to_excel(r"C:/Users/user/Desktop/구청별 업무추진비(엑셀)/꺽기/하루에_일정비용이상사용_상호명같은것만분류/"+임시_구청이름+"_50만원이상.xlsx")

# %% [markdown]
# ## 휴일이용

# %%
for 임시_구청이름, 각_프레임 in 구청별.items():
    각_프레임[(각_프레임.요일 =='일') | (각_프레임.요일 =='토')].to_excel(파일위치경로+'/휴일사용//'+임시_구청이름+'(토_일).xlsx')

# %%
휴일이용_프레임 =pd.DataFrame(index =['금', '목', '수', '월', '일', '토', '화', '휴일이용비율', '합계'])
for 임시_구청이름, 각_프레임 in 구청별.items():
    임시_프레임 =각_프레임.groupby('요일')['자치구'].count()
    임시_합계 =임시_프레임.sum()
    임시_일 = 0
    임시_토 = 0
    try:
        임시_토 = 임시_프레임['토']
    except KeyError:
        pass
    try:
        임시_일 = 임시_프레임['일']
    except KeyError:
        pass
    임시_프레임['휴일이용비율'] = (임시_토+임시_일) / 임시_합계
    임시_프레임['합계']=임시_합계
    임시_프레임.name = 임시_구청이름
    휴일이용_프레임[임시_구청이름] = 임시_프레임
휴일이용_프레임.to_excel(파일위치경로+'/휴일사용//구청별_휴일이용비율.xlsx')

# %%
휴일이용_프레임
# Out:
#                 종로구           중구          용산구        성동구          광진구  \
# 금        521.000000   908.000000   960.000000   572.0000   672.000000
# 목        523.000000   959.000000   961.000000   634.0000   739.000000
# 수        536.000000   877.000000  1006.000000   633.0000   669.000000
# 월        541.000000   942.000000   983.000000   650.0000   843.000000
# 일        178.000000   243.000000   616.000000    58.0000     5.000000
# 토        307.000000   398.000000   721.000000   116.0000   233.000000
# 화        541.000000   974.000000   946.000000   645.0000   651.000000
# 휴일이용비율     0.154115     0.120921     0.215889     0.0526     0.062434
# 합계      3147.000000  5301.000000  6193.000000  3308.0000  3812.000000
#
#                동대문구          중랑구     성북구          강북구          도봉구  \
# 금        628.000000   666.000000   663.0   841.000000   645.000000
# 목        643.000000   642.000000   641.0   916.000000   657.000000
# 수        654.000000   667.000000   673.0   811.000000   582.000000
# 월        720.000000   665.000000   717.0   878.000000   658.000000
# 일        100.000000   123.000000     NaN   303.000000    10.000000
# 토        134.000000   252.000000     NaN   496.000000    30.000000
# 화        703.000000   634.000000   699.0   867.000000   629.000000
# 휴일이용비율     0.065327     0.102768     0.0     0.156299     0.012457
# 합계      3582.000000  3649.000000  3393.0  5112.000000  3211.000000
#
#            ...               강서구          구로구          금천구         영등포구  \
# 금          ...        573.000000   803.000000   816.000000   553.000000
# 목          ...        619.000000   694.000000   786.000000   502.000000
# 수          ...        551.000000   804.000000   752.000000   503.000000
# 월          ...        601.000000   776.000000   749.000000   538.000000
# 일          ...         84.000000   451.000000   255.000000    21.000000
# 토          ...        268.000000   520.000000   397.000000    59.000000
# 화          ...        590.000000   686.000000   787.000000   500.000000
# 휴일이용비율     ...          0.107121     0.205112     0.143549     0.029895
# 합계         ...       3286.000000  4734.000000  4542.000000  2676.000000
#
#                 동작구          관악구          서초구          강남구          송파구  \
# 금        536.000000   703.000000   683.000000   531.000000   801.000000
# 목        607.000000   723.000000   692.000000   580.000000   741.000000
# 수        578.000000   711.000000   718.000000   617.000000   676.000000
# 월        574.000000   737.000000   694.000000   586.000000   746.000000
# 일        220.000000   346.000000   343.000000     1.000000    46.000000
# 토        301.000000   493.000000   448.000000    10.000000    77.000000
# 화        596.000000   667.000000   699.000000   575.000000   720.000000
# 휴일이용비율     0.145775     0.191553     0.184943     0.003793     0.032309
# 합계      3574.000000  4380.000000  4277.000000  2900.000000  3807.000000
#
#                 강동구
# 금        220.000000
# 목        212.000000
# 수        231.000000
# 월        200.000000
# 일        170.000000
# 토        165.000000
# 화        246.000000
# 휴일이용비율     0.231994
# 합계      1444.000000
#
# [9 rows x 25 columns]
