# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot

# %%
파일위치경로 = r'C:/Users/user/Desktop/구청별 업무추진비(엑셀)/'
구청목록 = [ 
    '종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구',
    '은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서초구',
    '강남구','송파구','강동구','서울특별시'
            ]   #26개
극단값제거 = 500000

# %%
구청별금액사전=dict()

for count, 구청이름 in enumerate(구청목록):
    try:
        구청금액 = pd.read_excel(파일위치경로+구청이름+'(정제).xlsx',index_col='연번',parse_cols="A,J").집행금액
        구청별금액사전[구청이름] = 구청금액
    except FileNotFoundError:
        pass
    except ex:
        print(ex)
        print(구청이름)

# %%
구청별금액프레임 =pd.DataFrame()
구청식별코드 = dict()
count =0
for 구청이름 in 구청목록:
    try:
        구청별금액프레임 = pd.concat([구청별금액프레임,구청별금액사전[구청이름].reset_index(drop=True)],ignore_index=True,axis=1)
        구청식별코드[count] = 구청이름
        count+=1
    except KeyError:
        pass
    except:
        print(구청이름)

# %%
구청별금액프레임.head()
# Out:
#          0         1         2         3        4         5        6   \
# 0   59400.0   24000.0    7000.0   54000.0  21000.0   12000.0  28000.0
# 1  200000.0   38000.0   44000.0  220000.0  74000.0  153000.0   5000.0
# 2   77000.0  134000.0   12000.0  104000.0  51000.0   69000.0  33000.0
# 3   22000.0   50000.0    9000.0  136000.0  18000.0   42000.0  24000.0
# 4  120000.0   45000.0  116000.0  235000.0  96000.0  124000.0   6500.0
#
#          7          8         9     ...           15        16       17  \
# 0  129000.0  7000000.0   32000.0    ...     110000.0  101000.0  28000.0
# 1   45000.0   100000.0   84000.0    ...      10000.0  147000.0  84000.0
# 2   84000.0    20000.0  330000.0    ...      32000.0   92000.0  73000.0
# 3  149000.0    18000.0   72000.0    ...      63000.0  320000.0  66000.0
# 4   43000.0    56500.0  213000.0    ...      47000.0   32000.0  80000.0
#
#          18        19       20        21         22        23        24
# ...

# %%
구청별금액프레임.head()
# Out:
#          0         1         2         3        4         5        6   \
# 0   59400.0   24000.0    7000.0   54000.0  21000.0   12000.0  28000.0
# 1  200000.0   38000.0   44000.0  220000.0  74000.0  153000.0   5000.0
# 2   77000.0  134000.0   12000.0  104000.0  51000.0   69000.0  33000.0
# 3   22000.0   50000.0    9000.0  136000.0  18000.0   42000.0  24000.0
# 4  120000.0   45000.0  116000.0  235000.0  96000.0  124000.0   6500.0
#
#          7          8         9     ...           15        16       17  \
# 0  129000.0  7000000.0   32000.0    ...     110000.0  101000.0  28000.0
# 1   45000.0   100000.0   84000.0    ...      10000.0  147000.0  84000.0
# 2   84000.0    20000.0  330000.0    ...      32000.0   92000.0  73000.0
# 3  149000.0    18000.0   72000.0    ...      63000.0  320000.0  66000.0
# 4   43000.0    56500.0  213000.0    ...      47000.0   32000.0  80000.0
#
#          18        19       20        21         22        23        24
# ...

# %%
구청식별코드
# Out:
# {0: '종로구',
#  1: '중구',
#  2: '용산구',
#  3: '성동구',
#  4: '광진구',
#  5: '동대문구',
#  6: '중랑구',
#  7: '성북구',
#  8: '강북구',
#  9: '도봉구',
#  10: '노원구',
#  11: '은평구',
#  12: '서대문구',
#  13: '마포구',
#  14: '양천구',
#  15: '강서구',
#  16: '구로구',
#  17: '금천구',
#  18: '영등포구',
#  19: '동작구',
#  20: '관악구',
#  21: '서초구',
#  22: '강남구',
#  23: '송파구',
#  24: '강동구'}

# %% [markdown]
# ## 구청별 박스플롯 비교

# %%
구청별금액프레임.boxplot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
구청별금액프레임.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000013CA50F0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000141E4828>]], dtype=object)

# %%
#500000원 이하
구청별금액프레임_50만원이하=구청별금액프레임.copy()
for count in range(0,25):
    구청별금액프레임_50만원이하[count] = 구청별금액프레임_50만원이하[count].apply(lambda x : None if x>500000 else x)
구청별금액프레임_50만원이하.boxplot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
구청별금액프레임_50만원이하.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000014788E10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000014CC4CF8>]], dtype=object)

# %%
#500000원 이하
구청별금액프레임_20만원이하=구청별금액프레임.copy()
for count in range(0,25):
    구청별금액프레임_20만원이하[count] = 구청별금액프레임_20만원이하[count].apply(lambda x : None if x>200000 else x)
구청별금액프레임_20만원이하.boxplot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
구청별금액프레임_20만원이하.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000152CD3C8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000167D7860>]], dtype=object)

# %%
구청별금액프레임.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000114CEC88>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011BFE0F0>]], dtype=object)
