# %%
# %matplotlib notebook
import pandas as pd
import numpy as np

# %%
파일위치경로 = r'C:/Users/user/Desktop/구청별 업무추진비(엑셀)/'
구청목록 = [ 
    '종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구',
    '은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서초구',
    '강남구','송파구','강동구','서울특별시'
            ]   #26개
극단값제거 = 500000
결재방법_변환키 ={'-':'카드', '현금':'현금', '계좌이체':'현금', '무통장입금':'현금', '법인카드':'카드', '카드':'카드', '국내':'카드'}

# %%
구청별금액사전=dict()

for count, 구청이름 in enumerate(구청목록):
    try:
        구청금액 = pd.read_excel(파일위치경로+구청이름+'(정제).xlsx',index_col='연번',parse_cols='A,J')
        try:
            구청금액 = 구청금액.astype(str)['집행금액'].apply(lambda x : x.replace(',','').replace(' ','')).astype(np.int64)
        except AttributeError:
            pass
        #구청금액 = 구청금액[구청금액<극단값제거].reset_index(drop=True)
        구청별금액사전[구청이름] = 구청금액.reset_index(drop=True)
    except FileNotFoundError:
        pass
    except:
        print(구청이름)

# %%
구청별금액프레임 =pd.DataFrame()
구청식별코드 = dict()
count =0
for 구청이름 in 구청목록:
    try:
        구청별금액프레임 = pd.concat([구청별금액프레임,구청별금액사전[구청이름]],ignore_index=True,axis=1)
        구청식별코드[count] = 구청이름
        count+=1
    except KeyError:
        pass

# %%
구청별금액프레임.describe().astype(np.int64)
# Out:
#            0       1       2       3       4        5       6       7   \
# count    3147    5301    6193    3308    3812     3582    3649    3393
# mean    93970   71671   56627  105963   88593   112883   83600   72300
# std     88348   81905   66067   93006   94258   109878   70755   87774
# min      1000    1000    1000    1000     500     2000    2500     500
# 25%     28000   16200   16000   30000   20000    30000   32000   18000
# 50%     60000   39000   31800   76000   51730    76000   64000   40000
# 75%    132000   97000   70000  160000  122850   163000  112000   87000
# max    496700  942000  600000  633500  494000  1370000  601000  498000
#
#             8        9    ...          15      16       17       18      19  \
# count     5112     3211   ...        3286    4734     4542     2676    3574
# mean     77497   122078   ...      113946   84938    79700   126157  102292
# std     162425    85937   ...      125769   84854    66253   118270  109739
# min       2000     2000   ...        3000    2000     3500     4100    1500
# 25%      24500    54000   ...       27000   25000    34000    41000   26000
# 50%      48000   110000   ...       61000   52000    61000    84000   60000
# 75%      98000   174000   ...      160000  118000   105000   174250  134000
# max    7000000  1120000   ...     1690000  636800  1428000  1170000  498000
#
#             20       21       22      23       24
# count     4380     4277     2900    3807     1444
# mean     99009    87255   119889  104966   133596
# std     129993    88712   139952  103408   139574
# min        900     1000     2500    1500     2500
# 25%      26000    27000    34000   33000    35000
# 50%      55000    60000    75000   66000    83000
# 75%     122000   116000   150000  142000   186000
# max    3300000  1669500  1734000  900000  1400000
#
# [8 rows x 25 columns]

# %% [markdown]
# ## 구분별 기초통계

# %%
구청별금액프레임 = pd.DataFrame()
for 구청이름 in 구청목록:
    try:
        구청별금액프레임=구청별금액프레임.append(pd.read_excel(파일위치경로+구청이름+'(정제).xlsx',parse_cols="B,D,I,J"))
    except FileNotFoundError:
        pass
    
구청별금액프레임.집행금액 = 구청별금액프레임.집행금액.astype(str).apply(lambda x : x.replace(',','').replace(' ','')).astype(np.float64)
구청별금액프레임 = 구청별금액프레임.reset_index(drop=True)

# %%
구청별금액프레임
# Out:
#        자치구   구분   결재방법      집행금액
# 0      종로구   의장     카드   59400.0
# 1      종로구   의장     카드  200000.0
# 2      종로구   의장     카드   77000.0
# 3      종로구   의장     카드   22000.0
# 4      종로구   의장     카드  120000.0
# 5      종로구   의장     카드  113000.0
# 6      종로구   의장     카드  112000.0
# 7      종로구   의장     카드   31000.0
# 8      종로구   의장     카드   26000.0
# 9      종로구   의장     카드  155000.0
# 10     종로구   의장     카드   93000.0
# 11     종로구   의장     카드  155000.0
# 12     종로구   의장     카드   27000.0
# 13     종로구   의장     카드   16000.0
# 14     종로구   의장     카드  136000.0
# 15     종로구   의장     카드  150000.0
# 16     종로구   의장     카드   40000.0
# 17     종로구   의장     카드  116000.0
# 18     종로구   의장     카드  100000.0
# 19     종로구   의장     카드   25000.0
# 20     종로구   의장     카드   39000.0
# 21     종로구   의장     카드  125000.0
# 22     종로구   의장     카드   60000.0
# 23     종로구   의장     카드   54000.0
# 24     종로구   의장     카드  108000.0
# 25     종로구   의장     카드   19000.0
# 26     종로구   의장     카드   84000.0
# 27     종로구   의장     카드   45000.0
# 28     종로구   의장     카드  100000.0
# 29     종로구   의장     카드   39000.0
# ...    ...  ...    ...       ...
# 91708  강동구  부의장     카드   75000.0
# 91709  강동구  부의장     카드   67000.0
# 91710  강동구  부의장  무통장입금  483000.0
# 91711  강동구  부의장     카드  315300.0
# 91712  강동구  부의장     카드  156000.0
# 91713  강동구  부의장     카드  107000.0
# 91714  강동구  부의장     카드   90000.0
# 91715  강동구  부의장     카드   10000.0
# 91716  강동구  부의장     카드   92500.0
# 91717  강동구  부의장     카드   16200.0
# 91718  강동구  부의장     카드   37700.0
# 91719  강동구  부의장     카드  323000.0
# 91720  강동구  부의장     카드   48000.0
# 91721  강동구  부의장     카드   20000.0
# 91722  강동구  부의장     카드   20000.0
# 91723  강동구  부의장     카드   38000.0
# 91724  강동구  부의장     카드  257000.0
# 91725  강동구  부의장     카드  134000.0
# 91726  강동구  부의장     카드   27000.0
# 91727  강동구  부의장     카드   42000.0
# 91728  강동구  부의장     카드   41000.0
# 91729  강동구  부의장     카드  137900.0
# 91730  강동구  부의장     카드   54000.0
# 91731  강동구  부의장     카드  170000.0
# 91732  강동구  부의장     카드   58000.0
# 91733  강동구  부의장     카드  129000.0
# 91734  강동구  부의장     카드   16500.0
# 91735  강동구  부의장     카드   99500.0
# 91736  강동구  부의장     카드   77400.0
# 91737  강동구  부의장     카드   40000.0
#
# [91738 rows x 4 columns]

# %%
구청별금액프레임.결재방법=구청별금액프레임.결재방법.apply(lambda x : 결재방법_변환키[x.strip()])
구청별금액프레임.head()
# Out:
#    자치구  구분 결재방법      집행금액
# 0  종로구  의장   카드   59400.0
# 1  종로구  의장   카드  200000.0
# 2  종로구  의장   카드   77000.0
# 3  종로구  의장   카드   22000.0
# 4  종로구  의장   카드  120000.0

# %%
자치구별_통계 = 구청별금액프레임.groupby('자치구').agg([len,sum,np.mean])

# %%
자치구별_통계.T
# Out:
# 자치구                 강남구           강동구           강북구           강서구  \
# 집행금액 len   2.900000e+03  1.444000e+03  5.112000e+03  3.286000e+03
#      sum   3.476786e+08  1.929137e+08  3.961674e+08  3.744266e+08
#      mean  1.198892e+05  1.335967e+05  7.749753e+04  1.139460e+05
#
# 자치구                 관악구           광진구           구로구           금천구  \
# 집행금액 len   4.380000e+03  3.812000e+03  4.734000e+03  4.542000e+03
#      sum   4.336603e+08  3.377203e+08  4.020973e+08  3.620008e+08
#      mean  9.900919e+04  8.859400e+04  8.493818e+04  7.970074e+04
#
# 자치구                 노원구           도봉구      ...                성동구  \
# 집행금액 len   3.479000e+03  3.211000e+03      ...       3.308000e+03
#      sum   4.403333e+08  3.919926e+08      ...       3.505285e+08
#      mean  1.265689e+05  1.220780e+05      ...       1.059639e+05
#
# 자치구                 성북구           송파구           양천구          영등포구  \
# 집행금액 len   3.393000e+03  3.807000e+03  3.005000e+03  2.676000e+03
#      sum   2.453151e+08  3.996072e+08  3.682413e+08  3.375964e+08
#      mean  7.230034e+04  1.049664e+05  1.225429e+05  1.261571e+05
#
# 자치구                 용산구           은평구           종로구            중구  \
# 집행금액 len   6.193000e+03  3.100000e+03  3.147000e+03  5.301000e+03
#      sum   3.506920e+08  3.512233e+08  2.957240e+08  3.799321e+08
#      mean  5.662716e+04  1.132978e+05  9.397014e+04  7.167178e+04
#
# 자치구                 중랑구
# 집행금액 len   3.649000e+03
#      sum   3.050574e+08
#      mean  8.360027e+04
#
# [3 rows x 25 columns]

# %%
구분별_결재별_통계 = pd.pivot_table(구청별금액프레임,columns=['자치구','구분','결재방법'],aggfunc=[len,np.sum,np.mean])

# %%
구분별_결재별_통계
# Out:
#                           len          sum           mean
#      자치구 구분      결재방법
# 집행금액 강남구 복지도시위원장 카드     522.0   49467790.0   94765.881226
#          부의장     카드     515.0   65647900.0  127471.650485
#          운영위원장   카드     503.0   49610530.0   98629.284294
#          의장      카드     749.0  130382390.0  174075.287049
#                  현금       7.0    5315000.0  759285.714286
#          행정재경위원장 카드     604.0   47255024.0   78236.794702
#      강동구 부의장     카드     479.0   60159940.0  125594.864301
#                  현금       3.0    1083000.0  361000.000000
#          의장      카드     942.0  126690750.0  134491.242038
#                  현금      20.0    4980000.0  249000.000000
#      강북구 복지건설위원장 카드     900.0   53376720.0   59307.466667
#                  현금       4.0     300000.0   75000.000000
#          부의장     카드    1232.0   79559370.0   64577.410714
#          운영위원장   카드     728.0   52118020.0   71590.686813
#                  현금       3.0     200000.0   66666.666667
#          의장      카드    1439.0  139744130.0   97111.973593
#                  현금      33.0   27675000.0  838636.363636
#          행정보건위원장 카드     772.0   43144150.0   55886.204663
#                  현금       1.0      50000.0   50000.000000
#      강서구 복지건설위원장 카드     675.0   49957700.0   74011.407407
#          부의장     카드     540.0   69556535.0  128808.398148
#                  현금       1.0     100000.0  100000.000000
#          운영위원장   카드     406.0   51370340.0  126527.931034
#          의장      카드    1087.0  150405390.0  138367.424103
#                  현금       3.0    1688000.0  562666.666667
#          행정재무위원장 카드     574.0   51348650.0   89457.578397
#      관악구 도시건설위원장 카드     481.0   50927620.0  105878.627859
#          보건복지위원장 카드     422.0   51163580.0  121240.710900
#          부의장     카드     666.0   73241130.0  109971.666667
#          의장      카드    1458.0  155506890.0  106657.674897
# ...                       ...          ...            ...
#      용산구 복지건설위원장 카드     792.0   50235054.0   63428.098485
#          부의장     카드     970.0   74354224.0   76653.839175
#          운영위원장   카드     875.0   50563840.0   57787.245714
#          의장      카드    2332.0  123241370.0   52847.928816
#          행정위원장   카드    1224.0   52297543.0   42726.750817
#      은평구 부의장     카드     651.0   68997120.0  105986.359447
#                  현금       1.0     370000.0  370000.000000
#          운영위원장   카드     563.0   47276580.0   83972.611012
#          의장      카드     874.0  137426551.0  157238.616705
#                  현금      15.0    1600000.0  106666.666667
#          재무건설위원장 카드     437.0   47706970.0  109169.267735
#                  현금       1.0     220000.0  220000.000000
#          행정복지위원장 카드     557.0   47446059.0   85181.434470
#                  현금       1.0     180000.0  180000.000000
#      종로구 건설복지위원장 카드     481.0   42443490.0   88240.103950
#          부의장     카드     557.0   59457740.0  106746.391382
#          운영위원장   카드     444.0   39773020.0   89578.873874
#          의장      카드    1205.0  110228900.0   91476.265560
#          행정문화위원장 카드     460.0   43820890.0   95262.804348
#      중구  복지건설위원장 카드     890.0   53017500.0   59570.224719
#          부의장     카드    1006.0   74468505.0   74024.358847
#          의장      카드    1591.0  149446209.0   93932.249529
#                  현금       2.0     100000.0   50000.000000
#          의회운영위원장 카드     836.0   48761129.0   58326.709330
#          행정보건위원장 카드     976.0   54138770.0   55470.051230
#      중랑구 복지건설위원장 카드     799.0   49781400.0   62304.630788
#          부의장     카드     787.0   65611540.0   83369.174079
#          운영위원장   카드     491.0   39160718.0   79757.063136
#          의장      카드    1053.0  105706560.0  100386.096866
#          행정재경위원장 카드     519.0   44797160.0   86314.373796
#
# [163 rows x 3 columns]

# %%
결재별_통계 =pd.pivot_table(구청별금액프레임[['자치구','결재방법','집행금액']],columns=['자치구','결재방법'],aggfunc=[len,np.sum])

# %%
결재별_통계
# Out:
#                    len          sum
#      자치구  결재방법
# 집행금액 강남구  카드    2893.0  342363634.0
#           현금       7.0    5315000.0
#      강동구  카드    1421.0  186850690.0
#           현금      23.0    6063000.0
#      강북구  카드    5071.0  367942390.0
#           현금      41.0   28225000.0
#      강서구  카드    3282.0  372638615.0
#           현금       4.0    1788000.0
#      관악구  카드    4380.0  433660260.0
#      광진구  카드    3812.0  337720326.0
#      구로구  카드    4734.0  402097346.0
#      금천구  카드    4515.0  358950778.0
#           현금      27.0    3050000.0
#      노원구  카드    3479.0  440333336.0
#      도봉구  카드    3209.0  391892560.0
#           현금       2.0     100000.0
#      동대문구 카드    3582.0  404347290.0
#      동작구  카드    3574.0  365593830.0
#      마포구  카드    2971.0  351285402.0
#      서대문구 카드    2855.0  348124290.0
#      서초구  카드    4263.0  372391970.0
#           현금      14.0     800000.0
#      성동구  카드    3308.0  350528452.0
#      성북구  카드    3393.0  245315060.0
#      송파구  카드    3807.0  399607180.0
#      양천구  카드    3005.0  368241300.0
#      영등포구 카드    2676.0  337596450.0
#      용산구  카드    6193.0  350692031.0
#      은평구  카드    3082.0  348853280.0
#           현금      18.0    2370000.0
#      종로구  카드    3147.0  295724040.0
#      중구   카드    5299.0  379832113.0
#           현금       2.0     100000.0
#      중랑구  카드    3649.0  305057378.0

# %%
구분별_통계 = pd.pivot_table(구청별금액프레임[['자치구','구분','집행금액']],columns=['자치구','구분'],aggfunc=[len,np.sum,np.mean])

# %%
구분별_통계
# Out:
#                       len          sum           mean
#      자치구  구분
# 집행금액 강남구  복지도시위원장   522.0   49467790.0   94765.881226
#           부의장       515.0   65647900.0  127471.650485
#           운영위원장     503.0   49610530.0   98629.284294
#           의장        756.0  135697390.0  179493.902116
#           행정재경위원장   604.0   47255024.0   78236.794702
#      강동구  부의장       482.0   61242940.0  127060.041494
#           의장        962.0  131670750.0  136871.881497
#      강북구  복지건설위원장   904.0   53676720.0   59376.902655
#           부의장      1232.0   79559370.0   64577.410714
#           운영위원장     731.0   52318020.0   71570.478796
#           의장       1472.0  167419130.0  113735.822011
#           행정보건위원장   773.0   43194150.0   55878.589909
#      강서구  복지건설위원장   675.0   49957700.0   74011.407407
#           부의장       541.0   69656535.0  128755.147874
#           운영위원장     406.0   51370340.0  126527.931034
#           의장       1090.0  152093390.0  139535.220183
#           행정재무위원장   574.0   51348650.0   89457.578397
#      관악구  도시건설위원장   481.0   50927620.0  105878.627859
#           보건복지위원장   422.0   51163580.0  121240.710900
#           부의장       666.0   73241130.0  109971.666667
#           의장       1458.0  155506890.0  106657.674897
#           의회운영위원장   649.0   50945610.0   78498.628659
#           행정재경위원장   704.0   51875430.0   73686.690341
#      광진구  기획행정위원장   979.0   47846510.0   48872.839632
#           복지건설위원장   540.0   47027900.0   87088.703704
#           부의장       767.0   64038386.0   83492.028683
#           의장        986.0  131363960.0  133229.168357
#           의회운영위원장   540.0   47443570.0   87858.462963
#      구로구  복지건설위원장   945.0   55915120.0   59169.439153
#           부의장      1002.0   80139651.0   79979.691617
# ...                   ...          ...            ...
#      영등포구 부의장       473.0   65184350.0  137810.465116
#           사회건설위원장   486.0   46835290.0   96368.909465
#           운영위원장     426.0   45236700.0  106189.436620
#           의장        805.0  135548860.0  168383.677019
#           행정위원장     486.0   44791250.0   92163.065844
#      용산구  복지건설위원장   792.0   50235054.0   63428.098485
#           부의장       970.0   74354224.0   76653.839175
#           운영위원장     875.0   50563840.0   57787.245714
#           의장       2332.0  123241370.0   52847.928816
#           행정위원장    1224.0   52297543.0   42726.750817
#      은평구  부의장       652.0   69367120.0  106391.288344
#           운영위원장     563.0   47276580.0   83972.611012
#           의장        889.0  139026551.0  156385.321710
#           재무건설위원장   438.0   47926970.0  109422.305936
#           행정복지위원장   558.0   47626059.0   85351.360215
#      종로구  건설복지위원장   481.0   42443490.0   88240.103950
#           부의장       557.0   59457740.0  106746.391382
#           운영위원장     444.0   39773020.0   89578.873874
#           의장       1205.0  110228900.0   91476.265560
#           행정문화위원장   460.0   43820890.0   95262.804348
#      중구   복지건설위원장   890.0   53017500.0   59570.224719
#           부의장      1006.0   74468505.0   74024.358847
#           의장       1593.0  149546209.0   93877.092906
#           의회운영위원장   836.0   48761129.0   58326.709330
#           행정보건위원장   976.0   54138770.0   55470.051230
#      중랑구  복지건설위원장   799.0   49781400.0   62304.630788
#           부의장       787.0   65611540.0   83369.174079
#           운영위원장     491.0   39160718.0   79757.063136
#           의장       1053.0  105706560.0  100386.096866
#           행정재경위원장   519.0   44797160.0   86314.373796
#
# [142 rows x 3 columns]

# %%
구분별_통계.to_excel('C:/Users/user/Desktop/구청별 업무추진비(엑셀)/통계/구분별_통계.xlsx')

# %%
구분별_결재별_통계.to_excel('C:/Users/user/Desktop/구청별 업무추진비(엑셀)/통계/구분별_결재별_통계.xlsx')

# %%
결재별_통계.to_excel('C:/Users/user/Desktop/구청별 업무추진비(엑셀)/통계/결재별_통계.xlsx')

# %%
자치구별_통계.to_excel('C:/Users/user/Desktop/구청별 업무추진비(엑셀)/통계/자치구별_통계.xlsx')
